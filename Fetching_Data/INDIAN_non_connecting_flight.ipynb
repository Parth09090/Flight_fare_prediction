# %%
import requests
import json
import csv
import os
from datetime import datetime, timedelta
from itertools import combinations
import random
import time
import logging

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('flight_scraper.log'),
        logging.StreamHandler()
    ]
)

# Define your routes
top_400_routes = [
    ("DEL", "BOM"), ("DEL", "BLR"), ("DEL", "HYD"), ("DEL", "MAA"), ("DEL", "CCU"),
    ("BOM", "BLR"), ("BOM", "HYD"), ("BOM", "MAA"), ("BOM", "CCU"), ("BOM", "PNQ"),
    ("BLR", "HYD"), ("BLR", "MAA"), ("BLR", "CCU"), ("BLR", "AMD"), ("BLR", "COK"),
    ("HYD", "MAA"), ("HYD", "CCU"), ("HYD", "PNQ"), ("HYD", "JAI"), ("HYD", "IXC"),
    ("MAA", "CCU"), ("MAA", "COK"), ("MAA", "IXM"), ("MAA", "TRV"), ("MAA", "BOM"),
    ("CCU", "GAU"), ("CCU", "IXB"), ("CCU", "PAT"), ("CCU", "DEL"), ("CCU", "BLR"),
    ("PNQ", "DEL"), ("PNQ", "BLR"), ("PNQ", "HYD"), ("PNQ", "MAA"), ("PNQ", "AMD"),
    ("AMD", "DEL"), ("AMD", "BOM"), ("AMD", "BLR"), ("AMD", "HYD"), ("AMD", "MAA"),
    ("COK", "BLR"), ("COK", "MAA"), ("COK", "DEL"), ("COK", "HYD"), ("COK", "BOM"),
    ("GOI", "DEL"), ("GOI", "BOM"), ("GOI", "BLR"), ("GOI", "HYD"), ("GOI", "PNQ"),
    ("JAI", "DEL"), ("JAI", "BOM"), ("JAI", "HYD"), ("JAI", "AMD"), ("JAI", "BLR"),
    ("LKO", "DEL"), ("LKO", "BOM"), ("LKO", "BLR"), ("LKO", "HYD"), ("LKO", "CCU"),
    ("IXC", "DEL"), ("IXC", "BOM"), ("IXC", "BLR"), ("IXC", "HYD"), ("IXC", "PNQ"),
    ("TRV", "DEL"), ("TRV", "BLR"), ("TRV", "MAA"), ("TRV", "HYD"), ("TRV", "COK"),
    ("IXB", "DEL"), ("IXB", "CCU"), ("IXB", "BLR"), ("IXB", "GAU"), ("IXB", "HYD"),
    ("GAU", "DEL"), ("GAU", "CCU"), ("GAU", "BLR"), ("GAU", "HYD"), ("GAU", "IXB"),
    ("PAT", "DEL"), ("PAT", "CCU"), ("PAT", "HYD"), ("PAT", "BLR"), ("PAT", "BOM"),
    ("NAG", "DEL"), ("NAG", "BOM"), ("NAG", "HYD"), ("NAG", "BLR"), ("NAG", "MAA"),
    ("VGA", "DEL"), ("VGA", "HYD"), ("VGA", "BLR"), ("VGA", "MAA"), ("VGA", "BOM"),
    ("RPR", "DEL"), ("RPR", "BOM"), ("RPR", "BLR"), ("RPR", "HYD"), ("RPR", "MAA"),
    ("BHO", "DEL"), ("BHO", "BOM"), ("BHO", "BLR"), ("BHO", "HYD"), ("BHO", "PNQ"),
    ("SXR", "DEL"), ("SXR", "IXC"), ("SXR", "BOM"), ("SXR", "BLR"), ("SXR", "HYD"),
    ("IXZ", "MAA"), ("IXZ", "CCU"), ("IXZ", "DEL"), ("IXZ", "BLR"), ("IXZ", "BOM"),
]

# Convert to set and add more routes
route_set = set(top_400_routes)
core_airports = [
    "DEL", "BOM", "BLR", "HYD", "MAA", "CCU", "PNQ", "AMD", "COK", "JAI",
    "LKO", "IXC", "TRV", "IXB", "GAU", "PAT", "NAG", "RPR", "BHO", "SXR", "IXZ", "VGA"
]

all_possible_routes = list(combinations(core_airports, 2))
random.shuffle(all_possible_routes)

for route in all_possible_routes:
    if len(route_set) >= 400:
        break
    if route not in route_set:
        route_set.add(route)

# Final list of routes
routes = list(route_set)

# FIXED DEPARTURE DATE - August 31, 2025
FIXED_DEPARTURE_DATE = datetime(2025, 8, 31)

def fetch_flight_data(origin, destination, departure_date):
    """Fetch flight data for a specific route and date"""
    url = "http://www.nomadiq.co.in/api/search"
    headers = {
        "Accept": "application/json, text/plain, */*",
        "Content-Type": "application/json"
    }
    
    payload = {
        "UserIp": "127.0.0.1",
        "Adult": 1,
        "Child": 0,
        "Infant": 0,
        "JourneyType": 1,
        "CabinClass": 1,
        "AirSegments": [
            {
                "Origin": origin,
                "Destination": destination,
                "PreferredTime": departure_date.strftime("%Y-%m-%dT00:00:00")
            }
        ],
        "DirectFlight": True,
        "PreferredCarriers": []
    }
    
    try:
        response = requests.post(url, headers=headers, json=payload, timeout=30)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        logging.error(f"Request failed for {origin}-{destination}: {e}")
        return None

def parse_flight_data(data, origin, destination, search_date, departure_date):
    """Parse flight data and extract relevant information"""
    flights = []
    
    if not data or 'Result' not in data or not data['Result']:
        return flights
    
    # Calculate days before departure
    days_before_departure = (departure_date.date() - search_date.date()).days
    
    try:
        for flight_group in data['Result']:
            for flight in flight_group:
                # Extract segment information
                if 'Segments' not in flight or not flight['Segments']:
                    continue
                
                segment = flight['Segments'][0][0]  # First segment (direct flight)
                
                # Basic flight information
                flight_info = {
                    'search_date': search_date.strftime("%Y-%m-%d"),
                    'departure_date': departure_date.strftime("%Y-%m-%d"),
                    'days_before_departure': days_before_departure,
                    'origin': origin,
                    'destination': destination,
                    'departure_time': segment['Origin']['DepartTime'],
                    'arrival_time': segment['Destination']['ArrivalTime'],
                    'duration_minutes': segment['Duration'],
                    'airline_code': segment['Airline']['AirlineCode'],
                    'airline_name': segment['Airline']['AirlineName'],
                    'flight_number': segment['Airline']['FlightNumber'],
                    'aircraft': segment['Craft'],
                    'origin_terminal': segment['Origin'].get('Terminal', ''),
                    'destination_terminal': segment['Destination'].get('Terminal', ''),
                }
                
                # Extract fare information
                if 'FareList' in flight and flight['FareList']:
                    # Get minimum and maximum prices
                    prices = [fare['PublishedPrice'] for fare in flight['FareList']]
                    flight_info['min_price'] = min(prices)
                    flight_info['max_price'] = max(prices)
                    flight_info['min_published_price'] = flight.get('MinPublishedPrice', min(prices))
                    
                    # Get details from the cheapest fare
                    cheapest_fare = min(flight['FareList'], key=lambda x: x['PublishedPrice'])
                    flight_info['cabin_class'] = cheapest_fare['CabinClass']
                    flight_info['is_refundable'] = cheapest_fare['IsRefundable']
                    flight_info['fare_type'] = cheapest_fare['FareType']
                    
                    # Baggage information
                    if cheapest_fare['SeatBaggage']:
                        baggage = cheapest_fare['SeatBaggage'][0][0]
                        flight_info['checkin_baggage'] = baggage.get('CheckIn', '')
                        flight_info['cabin_baggage'] = baggage.get('Cabin', '')
                        flight_info['seats_available'] = baggage.get('NoOfSeatAvailable', '')
                else:
                    # Set default values if no fare information
                    flight_info.update({
                        'min_price': None,
                        'max_price': None,
                        'min_published_price': None,
                        'cabin_class': '',
                        'is_refundable': None,
                        'fare_type': '',
                        'checkin_baggage': '',
                        'cabin_baggage': '',
                        'seats_available': None
                    })
                
                flights.append(flight_info)
                
    except Exception as e:
        logging.error(f"Error parsing flight data for {origin}-{destination}: {e}")
    
    return flights

def save_to_csv(flights, filename='flight_non_connecting_india2.csv'):
    """Save flight data to CSV file"""
    if not flights:
        return
    
    # Check if file exists to determine if we need to write headers
    file_exists = os.path.isfile(filename)
    
    # Define CSV columns
    fieldnames = [
        'search_date', 'departure_date', 'days_before_departure', 'origin', 'destination', 
        'departure_time', 'arrival_time', 'duration_minutes', 'airline_code', 'airline_name', 
        'flight_number', 'aircraft', 'origin_terminal', 'destination_terminal', 'min_price',
        'max_price', 'min_published_price', 'cabin_class', 'is_refundable',
        'fare_type', 'checkin_baggage', 'cabin_baggage', 'seats_available'
    ]
    
    with open(filename, 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        # Write header only if file is new
        if not file_exists:
            writer.writeheader()
        
        # Write flight data
        writer.writerows(flights)

def main():
    """Main function to fetch flight data for all routes"""
    # Current date (when the search is performed)
    search_date = datetime.now()
    
    # Calculate days until departure
    days_until_departure = (FIXED_DEPARTURE_DATE.date() - search_date.date()).days
    
    # Check if departure date has passed
    if days_until_departure < 0:
        logging.error("Departure date has already passed! Please update FIXED_DEPARTURE_DATE.")
        return
    
    logging.info(f"Starting flight data collection")
    logging.info(f"Search date: {search_date.strftime('%Y-%m-%d')}")
    logging.info(f"Fixed departure date: {FIXED_DEPARTURE_DATE.strftime('%Y-%m-%d')}")
    logging.info(f"Days before departure: {days_until_departure}")
    logging.info(f"Total routes to process: {len(routes)}")
    
    all_flights = []
    successful_routes = 0
    failed_routes = 0
    
    for i, (origin, destination) in enumerate(routes, 1):
        logging.info(f"Processing route {i}/{len(routes)}: {origin} -> {destination}")
        
        # Fetch data for the fixed departure date
        data = fetch_flight_data(origin, destination, FIXED_DEPARTURE_DATE)
        
        if data:
            # Parse and store flight information
            flights = parse_flight_data(data, origin, destination, search_date, FIXED_DEPARTURE_DATE)
            if flights:
                all_flights.extend(flights)
                successful_routes += 1
                logging.info(f"Found {len(flights)} flights for {origin}-{destination}")
            else:
                logging.warning(f"No flights found for {origin}-{destination}")
                failed_routes += 1
        else:
            failed_routes += 1
        
        # Add delay to avoid overwhelming the API
        time.sleep(30)  # Adjust delay as needed
        
        # Save data periodically (every 10 routes)
        if i % 10 == 0 and all_flights:
            save_to_csv(all_flights)
            logging.info(f"Saved {len(all_flights)} flights to CSV")
            all_flights = []  # Clear the list after saving
    
    # Save any remaining flights
    if all_flights:
        save_to_csv(all_flights)
        logging.info(f"Saved final {len(all_flights)} flights to CSV")
    
    logging.info(f"Data collection complete!")
    logging.info(f"Successful routes: {successful_routes}")
    logging.info(f"Failed routes: {failed_routes}")
    
    # Save tracking information
    with open('collection_tracking.txt', 'a') as f:
        f.write(f"{search_date.strftime('%Y-%m-%d')}: Collected data {days_until_departure} days before departure\n")

# %%
main()
# Out:
# 2025-07-19 16:47:12,426 - INFO - Starting flight data collection
# 2025-07-19 16:47:12,430 - INFO - Search date: 2025-07-19
# 2025-07-19 16:47:12,432 - INFO - Fixed departure date: 2025-08-31
# 2025-07-19 16:47:12,432 - INFO - Days before departure: 43
# 2025-07-19 16:47:12,433 - INFO - Total routes to process: 318
# 2025-07-19 16:47:12,435 - INFO - Processing route 1/318: JAI -> IXC
# 2025-07-19 16:47:18,174 - INFO - Found 2 flights for JAI-IXC
# 2025-07-19 16:47:48,205 - INFO - Processing route 2/318: IXB -> DEL
# 2025-07-19 16:47:50,754 - INFO - Found 8 flights for IXB-DEL
# 2025-07-19 16:48:20,785 - INFO - Processing route 3/318: IXC -> BOM
# 2025-07-19 16:48:23,663 - WARNING - No flights found for IXC-BOM
# 2025-07-19 16:48:53,681 - INFO - Processing route 4/318: BOM -> PAT
# 2025-07-19 16:48:56,051 - INFO - Found 4 flights for BOM-PAT
# 2025-07-19 16:49:26,083 - INFO - Processing route 5/318: CCU -> SXR
# 2025-07-19 16:49:27,423 - WARNING - No flights found for CCU-SXR
# 2025-07-19 16:49:57,453 - INFO - Processing route 6/318: LKO -> BOM
# 2025-07-19 16:49:59,576 - INFO - Found 9 flights for LKO-BOM
# 2025-07-19 16:50:29,607 - INFO - Processing route 7/318: SXR -> VGA
# 2025-07-19 16:50:31,212 - WARNING - No flights found for SXR-VGA
# 2025-07-19 16:51:01,243 - INFO - Processing route 8/318: IXC -> RPR
# 2025-07-19 16:51:03,324 - WARNING - No flights found for IXC-RPR
# 2025-07-19 16:51:33,343 - INFO - Processing route 9/318: MAA -> COK
# 2025-07-19 16:51:35,352 - INFO - Found 6 flights for MAA-COK
# 2025-07-19 16:52:05,385 - INFO - Processing route 10/318: PNQ -> LKO
# 2025-07-19 16:52:06,973 - INFO - Found 1 flights for PNQ-LKO
# 2025-07-19 16:52:37,010 - INFO - Saved 30 flights to CSV
# 2025-07-19 16:52:37,011 - INFO - Processing route 11/318: IXB -> CCU
# 2025-07-19 16:52:38,273 - INFO - Found 5 flights for IXB-CCU
# 2025-07-19 16:53:08,305 - INFO - Processing route 12/318: PNQ -> BLR
# 2025-07-19 16:53:10,920 - INFO - Found 15 flights for PNQ-BLR
# 2025-07-19 16:53:40,951 - INFO - Processing route 13/318: JAI -> VGA
# 2025-07-19 16:53:42,326 - WARNING - No flights found for JAI-VGA
# 2025-07-19 16:54:12,358 - INFO - Processing route 14/318: IXC -> DEL
# 2025-07-19 16:54:25,473 - INFO - Found 7 flights for IXC-DEL
# 2025-07-19 16:54:55,485 - INFO - Processing route 15/318: CCU -> PAT
# 2025-07-19 16:54:57,445 - INFO - Found 2 flights for CCU-PAT
# 2025-07-19 16:55:27,476 - INFO - Processing route 16/318: DEL -> PAT
# 2025-07-19 17:26:47,729 - INFO - Processing route 74/318: CCU -> PNQ
# 2025-07-19 17:26:49,119 - INFO - Found 4 flights for CCU-PNQ
# 2025-07-19 17:27:19,151 - INFO - Processing route 75/318: AMD -> TRV
# 2025-07-19 17:27:21,742 - WARNING - No flights found for AMD-TRV
# 2025-07-19 17:27:51,774 - INFO - Processing route 76/318: DEL -> VGA
# 2025-07-19 17:27:54,708 - INFO - Found 3 flights for DEL-VGA
# 2025-07-19 17:28:24,739 - INFO - Processing route 77/318: GOI -> DEL
# 2025-07-19 17:28:27,494 - INFO - Found 15 flights for GOI-DEL
# 2025-07-19 17:28:57,525 - INFO - Processing route 78/318: JAI -> NAG
# 2025-07-19 17:28:59,401 - WARNING - No flights found for JAI-NAG
# 2025-07-19 17:29:29,439 - INFO - Processing route 79/318: BOM -> TRV
# 2025-07-19 17:29:31,013 - INFO - Found 3 flights for BOM-TRV
# 2025-07-19 17:30:01,021 - INFO - Processing route 80/318: LKO -> VGA
# 2025-07-19 17:30:02,664 - WARNING - No flights found for LKO-VGA
# 2025-07-19 17:30:32,698 - INFO - Saved 27 flights to CSV
# 2025-07-19 17:30:32,700 - INFO - Processing route 81/318: MAA -> GAU
# 2025-07-19 17:30:34,409 - INFO - Found 3 flights for MAA-GAU
# 2025-07-19 17:31:04,420 - INFO - Processing route 82/318: AMD -> BOM
# 2025-07-19 17:31:06,616 - INFO - Found 17 flights for AMD-BOM
# 2025-07-19 17:31:36,637 - INFO - Processing route 83/318: TRV -> BHO
# 2025-07-19 17:31:37,858 - WARNING - No flights found for TRV-BHO
# 2025-07-19 17:32:07,889 - INFO - Processing route 84/318: MAA -> SXR
# 2025-07-19 17:32:09,630 - WARNING - No flights found for MAA-SXR
# 2025-07-19 17:32:39,661 - INFO - Processing route 85/318: IXZ -> MAA
# 2025-07-19 17:32:41,672 - INFO - Found 4 flights for IXZ-MAA
# 2025-07-19 17:33:11,704 - INFO - Processing route 86/318: HYD -> VGA
# 2025-07-19 17:33:13,819 - INFO - Found 6 flights for HYD-VGA
# 2025-07-19 17:33:43,825 - INFO - Processing route 87/318: VGA -> MAA
# 2025-07-19 17:33:45,350 - INFO - Found 2 flights for VGA-MAA
# 2025-07-19 17:34:15,381 - INFO - Processing route 88/318: CCU -> BHO
# 2025-07-19 17:34:16,681 - WARNING - No flights found for CCU-BHO
# 2025-07-19 17:34:46,712 - INFO - Processing route 89/318: DEL -> SXR
# 2025-07-19 17:34:48,708 - INFO - Found 9 flights for DEL-SXR
# 2025-07-19 17:35:18,737 - INFO - Processing route 90/318: PAT -> VGA
# 2025-07-19 17:35:20,171 - WARNING - No flights found for PAT-VGA
# 2025-07-19 17:35:50,211 - INFO - Saved 41 flights to CSV
# 2025-07-19 17:35:50,213 - INFO - Processing route 91/318: AMD -> RPR
# 2025-07-19 17:35:51,538 - INFO - Found 1 flights for AMD-RPR
# 2025-07-19 17:36:21,570 - INFO - Processing route 92/318: CCU -> JAI
# 2025-07-19 17:36:24,480 - INFO - Found 4 flights for CCU-JAI
# 2025-07-19 17:47:22,629 - INFO - Processing route 112/318: BOM -> CCU
# 2025-07-19 17:47:39,919 - INFO - Found 17 flights for BOM-CCU
# 2025-07-19 17:48:09,951 - INFO - Processing route 113/318: GAU -> NAG
# 2025-07-19 17:48:11,654 - WARNING - No flights found for GAU-NAG
# 2025-07-19 17:48:41,687 - INFO - Processing route 114/318: NAG -> MAA
# 2025-07-19 17:48:43,396 - WARNING - No flights found for NAG-MAA
# 2025-07-19 17:49:13,428 - INFO - Processing route 115/318: TRV -> COK
# 2025-07-19 17:49:15,046 - INFO - Found 1 flights for TRV-COK
# 2025-07-19 17:49:45,053 - INFO - Processing route 116/318: TRV -> DEL
# 2025-07-19 17:49:47,193 - INFO - Found 4 flights for TRV-DEL
# 2025-07-19 17:50:17,225 - INFO - Processing route 117/318: IXC -> HYD
# 2025-07-19 17:50:19,455 - INFO - Found 2 flights for IXC-HYD
# 2025-07-19 17:50:49,487 - INFO - Processing route 118/318: BLR -> NAG
# 2025-07-19 17:50:51,397 - INFO - Found 3 flights for BLR-NAG
# 2025-07-19 17:51:21,436 - INFO - Processing route 119/318: BHO -> HYD
# 2025-07-19 17:51:23,037 - INFO - Found 1 flights for BHO-HYD
# 2025-07-19 17:51:53,061 - INFO - Processing route 120/318: CCU -> DEL
# 2025-07-19 17:51:55,321 - INFO - Found 20 flights for CCU-DEL
# 2025-07-19 17:52:25,362 - INFO - Saved 53 flights to CSV
# 2025-07-19 17:52:25,364 - INFO - Processing route 121/318: BLR -> MAA
# 2025-07-19 17:52:27,663 - INFO - Found 11 flights for BLR-MAA
# 2025-07-19 17:52:57,696 - INFO - Processing route 122/318: SXR -> BOM
# 2025-07-19 17:52:59,809 - INFO - Found 2 flights for SXR-BOM
# 2025-07-19 17:53:29,841 - INFO - Processing route 123/318: RPR -> HYD
# 2025-07-19 17:53:31,617 - INFO - Found 3 flights for RPR-HYD
# 2025-07-19 17:54:01,649 - INFO - Processing route 124/318: AMD -> IXB
# 2025-07-19 17:54:03,101 - INFO - Found 1 flights for AMD-IXB
# 2025-07-19 17:54:33,133 - INFO - Processing route 125/318: PNQ -> VGA
# 2025-07-19 17:54:35,208 - WARNING - No flights found for PNQ-VGA
# 2025-07-19 17:55:05,242 - INFO - Processing route 126/318: BOM -> IXB
# 2025-07-19 17:55:07,005 - INFO - Found 3 flights for BOM-IXB
# 2025-07-19 17:55:37,037 - INFO - Processing route 127/318: TRV -> HYD
# 2025-07-19 17:55:39,041 - INFO - Found 2 flights for TRV-HYD
# 2025-07-19 17:56:09,079 - INFO - Processing route 128/318: COK -> IXC
# 2025-07-19 17:56:10,781 - WARNING - No flights found for COK-IXC
# 2025-07-19 17:56:40,789 - INFO - Processing route 129/318: JAI -> BOM
# 2025-07-19 17:56:48,580 - INFO - Found 9 flights for JAI-BOM
# 2025-07-19 17:57:18,612 - INFO - Processing route 130/318: IXZ -> BOM
# 2025-07-19 17:57:34,032 - WARNING - No flights found for IXZ-BOM
# 2025-07-19 17:58:04,077 - INFO - Saved 31 flights to CSV
# 2025-07-19 17:58:04,079 - INFO - Processing route 131/318: HYD -> AMD
# 2025-07-19 17:58:05,777 - INFO - Found 5 flights for HYD-AMD
# 2025-07-19 17:58:35,805 - INFO - Processing route 132/318: VGA -> BOM
# 2025-07-19 17:58:38,956 - INFO - Found 2 flights for VGA-BOM
# 2025-07-19 17:59:08,965 - INFO - Processing route 133/318: SXR -> DEL
# 2025-07-19 17:59:11,084 - INFO - Found 8 flights for SXR-DEL
# 2025-07-19 17:59:41,116 - INFO - Processing route 134/318: JAI -> RPR
# 2025-07-19 17:59:42,443 - WARNING - No flights found for JAI-RPR
# 2025-07-19 18:00:12,475 - INFO - Processing route 135/318: PNQ -> SXR
# 2025-07-19 18:00:14,301 - WARNING - No flights found for PNQ-SXR
# 2025-07-19 18:00:44,333 - INFO - Processing route 136/318: BLR -> PNQ
# 2025-07-19 18:00:47,042 - INFO - Found 15 flights for BLR-PNQ
# 2025-07-19 18:01:17,074 - INFO - Processing route 137/318: BOM -> MAA
# 2025-07-19 18:01:20,245 - INFO - Found 17 flights for BOM-MAA
# 2025-07-19 18:01:50,277 - INFO - Processing route 138/318: IXB -> BLR
# 2025-07-19 18:01:52,011 - INFO - Found 4 flights for IXB-BLR
# 2025-07-19 18:02:22,043 - INFO - Processing route 139/318: COK -> VGA
# 2025-07-19 18:02:23,619 - WARNING - No flights found for COK-VGA
# 2025-07-19 18:02:53,649 - INFO - Processing route 140/318: CCU -> IXB
# 2025-07-19 18:02:54,954 - INFO - Found 5 flights for CCU-IXB
# 2025-07-19 18:03:25,003 - INFO - Saved 56 flights to CSV
# 2025-07-19 18:03:25,005 - INFO - Processing route 141/318: DEL -> IXB
# 2025-07-19 18:03:27,106 - INFO - Found 7 flights for DEL-IXB
# 2025-07-19 18:03:57,139 - INFO - Processing route 142/318: PNQ -> TRV
# 2025-07-19 18:03:58,712 - WARNING - No flights found for PNQ-TRV
# 2025-07-19 18:04:28,745 - INFO - Processing route 143/318: JAI -> DEL
# 2025-07-19 18:04:30,390 - INFO - Found 4 flights for JAI-DEL
# 2025-07-19 18:05:00,422 - INFO - Processing route 144/318: NAG -> BHO
# 2025-07-19 18:05:01,710 - WARNING - No flights found for NAG-BHO
# 2025-07-19 18:05:31,741 - INFO - Processing route 145/318: IXZ -> DEL
# 2025-07-19 18:05:33,673 - INFO - Found 1 flights for IXZ-DEL
# 2025-07-19 18:06:03,705 - INFO - Processing route 146/318: GAU -> BHO
# 2025-07-19 18:06:05,094 - WARNING - No flights found for GAU-BHO
# 2025-07-19 18:06:35,125 - INFO - Processing route 147/318: MAA -> NAG
# 2025-07-19 18:06:40,619 - WARNING - No flights found for MAA-NAG
# 2025-07-19 18:07:10,652 - INFO - Processing route 148/318: VGA -> DEL
# 2025-07-19 18:07:28,533 - INFO - Found 3 flights for VGA-DEL
# 2025-07-19 18:07:58,566 - INFO - Processing route 149/318: BLR -> BHO
# 2025-07-19 18:08:00,098 - INFO - Found 2 flights for BLR-BHO
# 2025-07-19 18:08:30,132 - INFO - Processing route 150/318: COK -> BHO
# 2025-07-19 18:08:31,854 - WARNING - No flights found for COK-BHO
# 2025-07-19 18:09:01,898 - INFO - Saved 17 flights to CSV
# 2025-07-19 18:09:01,902 - INFO - Processing route 151/318: BLR -> JAI
# 2025-07-19 18:09:04,602 - INFO - Found 6 flights for BLR-JAI
# 2025-07-19 18:09:34,635 - INFO - Processing route 152/318: DEL -> NAG
# 2025-07-19 18:09:36,490 - INFO - Found 5 flights for DEL-NAG
# 2025-07-19 18:10:06,525 - INFO - Processing route 153/318: COK -> SXR
# 2025-07-19 18:10:07,874 - WARNING - No flights found for COK-SXR
# 2025-07-19 18:10:37,908 - INFO - Processing route 154/318: JAI -> HYD
# 2025-07-19 18:10:39,531 - INFO - Found 5 flights for JAI-HYD
# 2025-07-19 18:11:09,563 - INFO - Processing route 155/318: IXC -> BLR
# 2025-07-19 18:11:11,312 - INFO - Found 3 flights for IXC-BLR
# 2025-07-19 18:11:41,341 - INFO - Processing route 156/318: DEL -> MAA
# 2025-07-19 18:11:45,889 - INFO - Found 20 flights for DEL-MAA
# 2025-07-19 18:12:15,893 - INFO - Processing route 157/318: BOM -> PNQ
# 2025-07-19 18:12:17,254 - WARNING - No flights found for BOM-PNQ
# 2025-07-19 18:12:47,286 - INFO - Processing route 158/318: BHO -> BLR
# 2025-07-19 18:12:48,804 - INFO - Found 2 flights for BHO-BLR
# 2025-07-19 18:13:18,812 - INFO - Processing route 159/318: LKO -> NAG
# 2025-07-19 18:13:19,976 - WARNING - No flights found for LKO-NAG
# 2025-07-19 18:13:50,009 - INFO - Processing route 160/318: MAA -> IXC
# 2025-07-19 18:13:51,839 - INFO - Found 1 flights for MAA-IXC
# 2025-07-19 18:14:21,891 - INFO - Saved 42 flights to CSV
# 2025-07-19 18:14:21,895 - INFO - Processing route 161/318: BLR -> TRV
# 2025-07-19 18:14:25,277 - INFO - Found 6 flights for BLR-TRV
# 2025-07-19 18:14:55,312 - INFO - Processing route 162/318: IXZ -> CCU
# 2025-07-19 18:14:56,949 - INFO - Found 3 flights for IXZ-CCU
# 2025-07-19 18:15:26,959 - INFO - Processing route 163/318: COK -> TRV
# 2025-07-19 18:15:28,407 - INFO - Found 1 flights for COK-TRV
# 2025-07-19 18:15:58,440 - INFO - Processing route 164/318: RPR -> BLR
# 2025-07-19 18:16:00,123 - INFO - Found 2 flights for RPR-BLR
# 2025-07-19 18:16:30,156 - INFO - Processing route 165/318: NAG -> BOM
# 2025-07-19 18:16:33,405 - INFO - Found 6 flights for NAG-BOM
# 2025-07-19 18:17:03,437 - INFO - Processing route 166/318: AMD -> IXZ
# 2025-07-19 18:17:09,770 - WARNING - No flights found for AMD-IXZ
# 2025-07-19 18:17:39,802 - INFO - Processing route 167/318: HYD -> NAG
# 2025-07-19 18:17:41,208 - INFO - Found 2 flights for HYD-NAG
# 2025-07-19 18:18:11,241 - INFO - Processing route 168/318: IXB -> VGA
# 2025-07-19 18:18:12,910 - WARNING - No flights found for IXB-VGA
# 2025-07-19 18:18:42,942 - INFO - Processing route 169/318: PAT -> NAG
# 2025-07-19 18:18:44,125 - WARNING - No flights found for PAT-NAG
# 2025-07-19 18:19:14,158 - INFO - Processing route 170/318: LKO -> IXC
# 2025-07-19 18:19:15,731 - INFO - Found 1 flights for LKO-IXC
# 2025-07-19 18:19:45,779 - INFO - Saved 21 flights to CSV
# 2025-07-19 18:19:45,782 - INFO - Processing route 171/318: TRV -> BLR
# 2025-07-19 18:19:47,381 - INFO - Found 6 flights for TRV-BLR
# 2025-07-19 18:20:17,414 - INFO - Processing route 172/318: NAG -> RPR
# 2025-07-19 18:20:18,731 - WARNING - No flights found for NAG-RPR
# 2025-07-19 18:20:48,764 - INFO - Processing route 173/318: BHO -> IXZ
# 2025-07-19 18:20:50,704 - WARNING - No flights found for BHO-IXZ
# 2025-07-19 18:21:20,742 - INFO - Processing route 174/318: MAA -> PNQ
# 2025-07-19 18:21:22,873 - INFO - Found 7 flights for MAA-PNQ
# 2025-07-19 18:21:52,905 - INFO - Processing route 175/318: HYD -> IXC
# 2025-07-19 18:21:54,439 - INFO - Found 2 flights for HYD-IXC
# 2025-07-19 18:22:24,478 - INFO - Processing route 176/318: GAU -> RPR
# 2025-07-19 18:22:26,715 - WARNING - No flights found for GAU-RPR
# 2025-07-19 18:22:56,745 - INFO - Processing route 177/318: BLR -> RPR
# 2025-07-19 18:22:59,097 - INFO - Found 2 flights for BLR-RPR
# 2025-07-19 18:23:29,129 - INFO - Processing route 178/318: IXB -> GAU
# 2025-07-19 18:23:30,331 - INFO - Found 1 flights for IXB-GAU
# 2025-07-19 18:24:00,344 - INFO - Processing route 179/318: BOM -> JAI
# 2025-07-19 18:24:02,305 - INFO - Found 9 flights for BOM-JAI
# 2025-07-19 18:24:32,337 - INFO - Processing route 180/318: DEL -> PNQ
# 2025-07-19 18:24:35,612 - INFO - Found 22 flights for DEL-PNQ
# 2025-07-19 18:25:05,662 - INFO - Saved 49 flights to CSV
# 2025-07-19 18:25:05,664 - INFO - Processing route 181/318: COK -> RPR
# 2025-07-19 18:25:10,658 - WARNING - No flights found for COK-RPR
# 2025-07-19 18:25:40,689 - INFO - Processing route 182/318: IXB -> SXR
# 2025-07-19 18:25:42,197 - WARNING - No flights found for IXB-SXR
# 2025-07-19 18:26:12,230 - INFO - Processing route 183/318: NAG -> DEL
# 2025-07-19 18:26:15,071 - INFO - Found 5 flights for NAG-DEL
# 2025-07-19 18:26:45,073 - INFO - Processing route 184/318: TRV -> IXZ
# 2025-07-19 18:26:57,703 - WARNING - No flights found for TRV-IXZ
# 2025-07-19 18:27:27,735 - INFO - Processing route 185/318: GAU -> DEL
# 2025-07-19 18:27:33,619 - INFO - Found 13 flights for GAU-DEL
# 2025-07-19 18:28:03,645 - INFO - Processing route 186/318: IXC -> VGA
# 2025-07-19 18:28:11,699 - WARNING - No flights found for IXC-VGA
# 2025-07-19 18:28:41,725 - INFO - Processing route 187/318: CCU -> IXZ
# 2025-07-19 18:28:43,378 - INFO - Found 3 flights for CCU-IXZ
# 2025-07-19 18:29:13,410 - INFO - Processing route 188/318: COK -> DEL
# 2025-07-19 19:57:21,530 - INFO - Found 6 flights for JAI-BLR
# 2025-07-19 19:57:51,564 - INFO - Processing route 208/318: HYD -> BHO
# 2025-07-19 19:57:54,344 - INFO - Found 1 flights for HYD-BHO
# 2025-07-19 19:58:24,365 - INFO - Processing route 209/318: HYD -> SXR
# 2025-07-19 19:58:26,110 - WARNING - No flights found for HYD-SXR
# 2025-07-19 19:58:56,143 - INFO - Processing route 210/318: SXR -> IXZ
# 2025-07-19 19:58:57,826 - WARNING - No flights found for SXR-IXZ
# 2025-07-19 19:59:27,873 - INFO - Saved 25 flights to CSV
# 2025-07-19 19:59:27,877 - INFO - Processing route 211/318: AMD -> COK
# 2025-07-19 19:59:29,551 - INFO - Found 1 flights for AMD-COK
# 2025-07-19 19:59:59,583 - INFO - Processing route 212/318: MAA -> BOM
# 2025-07-19 20:00:02,146 - INFO - Found 17 flights for MAA-BOM
# 2025-07-19 20:00:32,179 - INFO - Processing route 213/318: IXZ -> BLR
# 2025-07-19 20:00:34,025 - INFO - Found 1 flights for IXZ-BLR
# 2025-07-19 20:01:04,057 - INFO - Processing route 214/318: PAT -> BHO
# 2025-07-19 20:01:05,460 - WARNING - No flights found for PAT-BHO
# 2025-07-19 20:01:35,493 - INFO - Processing route 215/318: TRV -> GAU
# 2025-07-19 20:01:37,318 - WARNING - No flights found for TRV-GAU
# 2025-07-19 20:02:07,350 - INFO - Processing route 216/318: LKO -> TRV
# 2025-07-19 20:02:08,872 - WARNING - No flights found for LKO-TRV
# 2025-07-19 20:02:38,904 - INFO - Processing route 217/318: PNQ -> NAG
# 2025-07-19 20:02:40,716 - INFO - Found 3 flights for PNQ-NAG
# 2025-07-19 20:03:10,748 - INFO - Processing route 218/318: BOM -> COK
# 2025-07-19 20:03:13,315 - INFO - Found 10 flights for BOM-COK
# 2025-07-19 20:03:43,347 - INFO - Processing route 219/318: DEL -> BOM
# 2025-07-19 20:03:47,073 - INFO - Found 52 flights for DEL-BOM
# 2025-07-19 20:04:17,105 - INFO - Processing route 220/318: PNQ -> MAA
# 2025-07-19 20:04:19,321 - INFO - Found 7 flights for PNQ-MAA
# 2025-07-19 20:04:49,360 - INFO - Saved 91 flights to CSV
# 2025-07-19 20:04:49,364 - INFO - Processing route 221/318: HYD -> TRV
# 2025-07-19 20:04:51,288 - INFO - Found 2 flights for HYD-TRV
# 2025-07-19 20:05:21,321 - INFO - Processing route 222/318: BLR -> IXB
# 2025-07-19 20:05:23,446 - INFO - Found 4 flights for BLR-IXB
# 2025-07-19 20:05:53,478 - INFO - Processing route 223/318: MAA -> RPR
# 2025-07-19 20:05:54,988 - INFO - Found 1 flights for MAA-RPR
# 2025-07-19 20:06:25,020 - INFO - Processing route 224/318: COK -> IXB
# 2025-07-19 20:06:26,636 - WARNING - No flights found for COK-IXB
# 2025-07-19 20:06:56,668 - INFO - Processing route 225/318: JAI -> IXZ
# 2025-07-19 20:07:07,378 - WARNING - No flights found for JAI-IXZ
# 2025-07-19 20:07:37,408 - INFO - Processing route 226/318: IXC -> PAT
# 2025-07-19 20:07:40,480 - WARNING - No flights found for IXC-PAT
# 2025-07-19 20:08:10,512 - INFO - Processing route 227/318: DEL -> RPR
# 2025-07-19 20:08:12,763 - INFO - Found 5 flights for DEL-RPR
# 2025-07-19 20:08:42,796 - INFO - Processing route 228/318: AMD -> HYD
# 2025-07-19 20:08:45,137 - INFO - Found 5 flights for AMD-HYD
# 2025-07-19 20:09:15,168 - INFO - Processing route 229/318: BOM -> HYD
# 2025-07-19 20:09:17,427 - INFO - Found 19 flights for BOM-HYD
# 2025-07-19 20:09:47,459 - INFO - Processing route 230/318: LKO -> RPR
# 2025-07-19 20:09:49,271 - INFO - Found 1 flights for LKO-RPR
# 2025-07-19 20:10:19,291 - INFO - Saved 37 flights to CSV
# 2025-07-19 20:10:19,293 - INFO - Processing route 231/318: PAT -> BOM
# 2025-07-19 20:10:21,337 - INFO - Found 4 flights for PAT-BOM
# 2025-07-19 20:10:51,369 - INFO - Processing route 232/318: HYD -> RPR
# 2025-07-19 20:10:53,097 - INFO - Found 3 flights for HYD-RPR
# 2025-07-19 20:11:23,130 - INFO - Processing route 233/318: COK -> NAG
# 2025-07-19 20:11:24,950 - WARNING - No flights found for COK-NAG
# 2025-07-19 20:11:54,982 - INFO - Processing route 234/318: CCU -> COK
# 2025-07-19 20:11:57,107 - WARNING - No flights found for CCU-COK
# 2025-07-19 20:12:27,138 - INFO - Processing route 235/318: DEL -> COK
# 2025-07-19 20:12:29,415 - INFO - Found 9 flights for DEL-COK
# 2025-07-19 20:12:59,447 - INFO - Processing route 236/318: TRV -> PAT
# 2025-07-19 20:13:01,141 - WARNING - No flights found for TRV-PAT
# 2025-07-19 20:13:31,173 - INFO - Processing route 237/318: COK -> MAA
# 2025-07-19 20:13:33,324 - INFO - Found 6 flights for COK-MAA
# 2025-07-19 20:14:03,355 - INFO - Processing route 238/318: PAT -> RPR
# 2025-07-19 20:14:05,263 - WARNING - No flights found for PAT-RPR
# 2025-07-19 20:14:35,276 - INFO - Processing route 239/318: LKO -> DEL
# 2025-07-19 20:14:37,471 - INFO - Found 10 flights for LKO-DEL
# 2025-07-19 20:15:07,500 - INFO - Processing route 240/318: MAA -> CCU
# 2025-07-19 20:15:10,038 - INFO - Found 7 flights for MAA-CCU
# 2025-07-19 20:15:40,080 - INFO - Saved 39 flights to CSV
# 2025-07-19 20:15:40,082 - INFO - Processing route 241/318: NAG -> BLR
# 2025-07-19 20:15:41,688 - INFO - Found 3 flights for NAG-BLR
# 2025-07-19 20:16:11,720 - INFO - Processing route 242/318: JAI -> GAU
# 2025-07-19 20:16:13,742 - INFO - Found 1 flights for JAI-GAU
# 2025-07-19 20:16:43,774 - INFO - Processing route 243/318: GOI -> BLR
# 2025-07-19 20:16:55,836 - INFO - Found 13 flights for GOI-BLR
# 2025-07-19 20:17:25,867 - INFO - Processing route 244/318: DEL -> HYD
# 2025-07-19 20:17:30,206 - INFO - Found 23 flights for DEL-HYD
# 2025-07-19 20:18:00,238 - INFO - Processing route 245/318: DEL -> CCU
# 2025-07-19 20:18:04,245 - INFO - Found 21 flights for DEL-CCU
# 2025-07-19 20:18:34,277 - INFO - Processing route 246/318: GAU -> BLR
# 2025-07-19 20:18:36,205 - INFO - Found 6 flights for GAU-BLR
# 2025-07-19 20:19:06,236 - INFO - Processing route 247/318: PAT -> DEL
# 2025-07-19 20:19:08,384 - INFO - Found 15 flights for PAT-DEL
# 2025-07-19 20:19:38,416 - INFO - Processing route 248/318: LKO -> CCU
# 2025-07-19 20:19:40,019 - INFO - Found 1 flights for LKO-CCU
# 2025-07-19 20:20:10,057 - INFO - Processing route 249/318: PNQ -> BHO
# 2025-07-19 20:20:11,771 - INFO - Found 1 flights for PNQ-BHO
# 2025-07-19 20:20:41,803 - INFO - Processing route 250/318: PNQ -> JAI
# 2025-07-19 20:20:43,848 - INFO - Found 4 flights for PNQ-JAI
# 2025-07-19 20:21:13,888 - INFO - Saved 88 flights to CSV
# 2025-07-19 20:21:13,890 - INFO - Processing route 251/318: MAA -> IXB
# 2025-07-19 20:21:15,497 - INFO - Found 1 flights for MAA-IXB
# 2025-07-19 20:21:45,514 - INFO - Processing route 252/318: HYD -> CCU
# 2025-07-19 20:21:47,549 - INFO - Found 8 flights for HYD-CCU
# 2025-07-19 20:22:17,582 - INFO - Processing route 253/318: IXB -> NAG
# 2025-07-19 20:22:19,614 - WARNING - No flights found for IXB-NAG
# 2025-07-19 20:22:49,646 - INFO - Processing route 254/318: NAG -> IXZ
# 2025-07-19 20:22:51,053 - WARNING - No flights found for NAG-IXZ
# 2025-07-19 20:23:21,085 - INFO - Processing route 255/318: CCU -> AMD
# 2025-07-19 20:23:23,119 - INFO - Found 5 flights for CCU-AMD
# 2025-07-19 20:23:53,151 - INFO - Processing route 256/318: PAT -> HYD
# 2025-07-19 20:23:54,890 - INFO - Found 5 flights for PAT-HYD
# 2025-07-19 20:24:24,922 - INFO - Processing route 257/318: GAU -> IXZ
# 2025-07-19 20:24:26,390 - WARNING - No flights found for GAU-IXZ
# 2025-07-19 20:24:56,399 - INFO - Processing route 258/318: PAT -> CCU
# 2025-07-19 20:24:58,423 - INFO - Found 2 flights for PAT-CCU
# 2025-07-19 20:25:28,435 - INFO - Processing route 259/318: BLR -> IXZ
# 2025-07-19 20:25:30,236 - INFO - Found 1 flights for BLR-IXZ
# 2025-07-19 20:26:00,263 - INFO - Processing route 260/318: SXR -> HYD
# 2025-07-19 20:26:01,988 - WARNING - No flights found for SXR-HYD
# 2025-07-19 20:26:32,025 - INFO - Saved 22 flights to CSV
# 2025-07-19 20:26:32,027 - INFO - Processing route 261/318: LKO -> IXB
# 2025-07-19 20:26:33,317 - WARNING - No flights found for LKO-IXB
# 2025-07-19 20:27:03,349 - INFO - Processing route 262/318: JAI -> PAT
# 2025-07-19 20:27:18,023 - WARNING - No flights found for JAI-PAT
# 2025-07-19 20:27:48,055 - INFO - Processing route 263/318: AMD -> LKO
# 2025-07-19 20:27:50,505 - INFO - Found 2 flights for AMD-LKO
# 2025-07-19 20:28:20,538 - INFO - Processing route 264/318: AMD -> BLR
# 2025-07-19 20:28:22,890 - INFO - Found 7 flights for AMD-BLR
# 2025-07-19 20:28:52,922 - INFO - Processing route 265/318: HYD -> IXB
# 2025-07-19 20:28:55,080 - INFO - Found 2 flights for HYD-IXB
# 2025-07-19 20:29:25,100 - INFO - Processing route 266/318: BOM -> LKO
# 2025-07-19 20:29:27,120 - INFO - Found 9 flights for BOM-LKO
# 2025-07-19 20:29:57,152 - INFO - Processing route 267/318: BOM -> BLR
# 2025-07-19 20:30:00,478 - INFO - Found 31 flights for BOM-BLR
# 2025-07-19 20:30:30,510 - INFO - Processing route 268/318: COK -> JAI
# 2025-07-19 20:30:32,253 - WARNING - No flights found for COK-JAI
# 2025-07-19 20:31:02,285 - INFO - Processing route 269/318: IXC -> NAG
# 2025-07-19 20:31:05,094 - WARNING - No flights found for IXC-NAG
# 2025-07-19 20:31:35,127 - INFO - Processing route 270/318: PNQ -> RPR
# 2025-07-19 20:31:36,858 - INFO - Found 1 flights for PNQ-RPR
# 2025-07-19 20:32:06,905 - INFO - Saved 52 flights to CSV
# 2025-07-19 20:32:06,908 - INFO - Processing route 271/318: VGA -> HYD
# 2025-07-19 20:32:09,954 - INFO - Found 6 flights for VGA-HYD
# 2025-07-19 20:32:39,980 - INFO - Processing route 272/318: RPR -> MAA
# 2025-07-19 20:32:41,704 - INFO - Found 1 flights for RPR-MAA
# 2025-07-19 20:33:11,736 - INFO - Processing route 273/318: HYD -> MAA
# 2025-07-19 20:33:14,192 - INFO - Found 13 flights for HYD-MAA
# 2025-07-19 20:33:44,224 - INFO - Processing route 274/318: BOM -> IXZ
# 2025-07-19 20:33:46,483 - WARNING - No flights found for BOM-IXZ
# 2025-07-19 20:34:16,515 - INFO - Processing route 275/318: PNQ -> COK
# 2025-07-19 20:34:18,016 - INFO - Found 2 flights for PNQ-COK
# 2025-07-19 20:34:48,044 - INFO - Processing route 276/318: PNQ -> DEL
# 2025-07-19 20:34:51,953 - INFO - Found 23 flights for PNQ-DEL
# 2025-07-19 20:35:21,964 - INFO - Processing route 277/318: JAI -> AMD
# 2025-07-19 20:35:29,762 - INFO - Found 3 flights for JAI-AMD
# 2025-07-19 20:35:59,800 - INFO - Processing route 278/318: COK -> BOM
# 2025-07-19 20:36:04,123 - INFO - Found 10 flights for COK-BOM
# 2025-07-19 20:36:34,155 - INFO - Processing route 279/318: CCU -> LKO
# 2025-07-19 20:36:41,650 - INFO - Found 1 flights for CCU-LKO
# 2025-07-19 20:37:11,652 - INFO - Processing route 280/318: DEL -> LKO
# 2025-07-19 20:37:29,365 - INFO - Found 10 flights for DEL-LKO
# 2025-07-19 20:37:59,407 - INFO - Saved 69 flights to CSV
# 2025-07-19 20:37:59,408 - INFO - Processing route 281/318: CCU -> BLR
# 2025-07-19 20:38:04,035 - INFO - Found 16 flights for CCU-BLR
# 2025-07-19 20:38:34,067 - INFO - Processing route 282/318: DEL -> BLR
# 2025-07-19 20:38:38,093 - INFO - Found 39 flights for DEL-BLR
# 2025-07-19 20:39:08,125 - INFO - Processing route 283/318: BLR -> AMD
# 2025-07-19 20:39:10,671 - INFO - Found 7 flights for BLR-AMD
# 2025-07-19 20:39:40,704 - INFO - Processing route 284/318: AMD -> VGA
# 2025-07-19 20:39:42,523 - WARNING - No flights found for AMD-VGA
# 2025-07-19 20:40:12,555 - INFO - Processing route 285/318: IXB -> BHO
# 2025-07-19 20:40:13,857 - WARNING - No flights found for IXB-BHO
# 2025-07-19 20:40:43,889 - INFO - Processing route 286/318: IXC -> PNQ
# 2025-07-19 20:40:45,817 - INFO - Found 1 flights for IXC-PNQ
# 2025-07-19 20:41:15,840 - INFO - Processing route 287/318: BOM -> VGA
# 2025-07-19 20:41:17,680 - INFO - Found 2 flights for BOM-VGA
# 2025-07-19 20:41:47,719 - INFO - Processing route 288/318: PNQ -> HYD
# 2025-07-19 20:41:50,681 - INFO - Found 9 flights for PNQ-HYD
# 2025-07-19 20:42:20,713 - INFO - Processing route 289/318: MAA -> IXZ
# 2025-07-19 20:42:22,643 - INFO - Found 4 flights for MAA-IXZ
# 2025-07-19 20:42:52,675 - INFO - Processing route 290/318: BLR -> COK
# 2025-07-19 20:42:55,123 - INFO - Found 14 flights for BLR-COK
# 2025-07-19 20:43:25,173 - INFO - Saved 92 flights to CSV
# 2025-07-19 20:43:25,176 - INFO - Processing route 291/318: BHO -> VGA
# 2025-07-19 20:43:27,814 - WARNING - No flights found for BHO-VGA
# 2025-07-19 20:43:57,847 - INFO - Processing route 292/318: DEL -> IXZ
# 2025-07-19 20:44:00,096 - INFO - Found 1 flights for DEL-IXZ
# 2025-07-19 20:44:30,129 - INFO - Processing route 293/318: HYD -> PNQ
# 2025-07-19 20:44:33,328 - INFO - Found 9 flights for HYD-PNQ
# 2025-07-19 20:45:03,360 - INFO - Processing route 294/318: PAT -> BLR
# 2025-07-19 20:45:05,138 - INFO - Found 6 flights for PAT-BLR
# 2025-07-19 20:45:35,148 - INFO - Processing route 295/318: GAU -> PAT
# 2025-07-19 20:45:37,122 - INFO - Found 2 flights for GAU-PAT
# 2025-07-19 20:46:07,152 - INFO - Processing route 296/318: AMD -> GAU
# 2025-07-19 20:46:09,921 - INFO - Found 1 flights for AMD-GAU
# 2025-07-19 20:46:39,952 - INFO - Processing route 297/318: AMD -> SXR
# 2025-07-19 20:46:41,046 - WARNING - No flights found for AMD-SXR
# 2025-07-19 20:47:11,062 - INFO - Processing route 298/318: LKO -> IXZ
# 2025-07-19 20:47:13,527 - WARNING - No flights found for LKO-IXZ
# 2025-07-19 20:47:43,567 - INFO - Processing route 299/318: SXR -> BLR
# 2025-07-19 20:47:44,065 - ERROR - Request failed for SXR-BLR: 504 Server Error: Gateway Timeout for url: https://www.nomadiq.co.in/api/search
# 2025-07-19 20:48:14,101 - INFO - Processing route 300/318: BOM -> GAU
# 2025-07-19 20:48:14,731 - ERROR - Request failed for BOM-GAU: 504 Server Error: Gateway Timeout for url: https://www.nomadiq.co.in/api/search
# 2025-07-19 20:48:44,779 - INFO - Saved 19 flights to CSV
# 2025-07-19 20:48:44,781 - INFO - Processing route 301/318: IXC -> BHO
# 2025-07-19 20:48:45,335 - ERROR - Request failed for IXC-BHO: 504 Server Error: Gateway Timeout for url: https://www.nomadiq.co.in/api/search
# 2025-07-19 20:49:15,371 - INFO - Processing route 302/318: TRV -> VGA
# 2025-07-19 20:49:17,210 - WARNING - No flights found for TRV-VGA
# 2025-07-19 20:49:47,242 - INFO - Processing route 303/318: BLR -> HYD
# 2025-07-19 20:49:51,048 - INFO - Found 21 flights for BLR-HYD
# 2025-07-19 20:50:21,081 - INFO - Processing route 304/318: BHO -> SXR
# 2025-07-19 20:50:23,518 - WARNING - No flights found for BHO-SXR
# 2025-07-19 20:50:53,552 - INFO - Processing route 305/318: PAT -> IXZ
# 2025-07-19 20:50:55,374 - WARNING - No flights found for PAT-IXZ
# 2025-07-19 20:51:25,406 - INFO - Processing route 306/318: CCU -> VGA
# 2025-07-19 20:51:27,020 - WARNING - No flights found for CCU-VGA
# 2025-07-19 20:51:57,054 - INFO - Processing route 307/318: COK -> HYD
# 2025-07-19 20:51:58,881 - INFO - Found 8 flights for COK-HYD
# 2025-07-19 20:52:28,912 - INFO - Processing route 308/318: SXR -> IXC
# 2025-07-19 20:52:30,734 - WARNING - No flights found for SXR-IXC
# 2025-07-19 20:53:00,767 - INFO - Processing route 309/318: RPR -> BHO
# 2025-07-19 20:53:02,489 - WARNING - No flights found for RPR-BHO
# 2025-07-19 20:53:32,516 - INFO - Processing route 310/318: IXB -> RPR
# 2025-07-19 20:53:34,030 - WARNING - No flights found for IXB-RPR
# 2025-07-19 20:54:04,069 - INFO - Saved 29 flights to CSV
# 2025-07-19 20:54:04,073 - INFO - Processing route 311/318: RPR -> SXR
# 2025-07-19 20:54:05,573 - WARNING - No flights found for RPR-SXR
# 2025-07-19 20:54:35,606 - INFO - Processing route 312/318: HYD -> JAI
# 2025-07-19 20:54:38,343 - INFO - Found 5 flights for HYD-JAI
# 2025-07-19 20:55:08,376 - INFO - Processing route 313/318: IXC -> TRV
# 2025-07-19 20:55:10,196 - WARNING - No flights found for IXC-TRV
# 2025-07-19 20:55:40,229 - INFO - Processing route 314/318: VGA -> BLR
# 2025-07-19 20:55:41,897 - INFO - Found 4 flights for VGA-BLR
# 2025-07-19 20:56:11,906 - INFO - Processing route 315/318: AMD -> PAT
# 2025-07-19 20:56:14,044 - INFO - Found 1 flights for AMD-PAT
# 2025-07-19 20:56:44,083 - INFO - Processing route 316/318: TRV -> SXR
# 2025-07-19 20:56:55,404 - WARNING - No flights found for TRV-SXR
# 2025-07-19 20:57:25,431 - INFO - Processing route 317/318: CCU -> GAU
# 2025-07-19 20:57:28,312 - INFO - Found 9 flights for CCU-GAU
# 2025-07-19 20:57:58,345 - INFO - Processing route 318/318: DEL -> GAU
# 2025-07-19 20:58:01,537 - INFO - Found 13 flights for DEL-GAU
# 2025-07-19 20:58:31,584 - INFO - Saved final 32 flights to CSV
# 2025-07-19 20:58:31,586 - INFO - Data collection complete!
# 2025-07-19 20:58:31,589 - INFO - Successful routes: 206
# 2025-07-19 20:58:31,591 - INFO - Failed routes: 112
